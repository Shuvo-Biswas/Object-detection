# %% [markdown]
# Setup
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.2-80-g55b0096 Python-3.7.13 torch-1.12.1+cu113 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 37.0/107.7 GB disk)

# %% [markdown]
# Link with drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/new_train_data.zip -d /content/drive/MyDrive
# Out:
# Archive:  /content/drive/MyDrive/new_train_data.zip
#    creating: /content/drive/MyDrive/new_train_data/
#    creating: /content/drive/MyDrive/new_train_data/images/
#    creating: /content/drive/MyDrive/new_train_data/images/train/
#   inflating: /content/drive/MyDrive/new_train_data/images/train/img (1).jpg
#   inflating: /content/drive/MyDrive/new_train_data/images/train/img (10).jpg
#   inflating: /content/drive/MyDrive/new_train_data/images/train/img (100).jpg
#   inflating: /content/drive/MyDrive/new_train_data/images/train/img (1000).jpg
#   inflating: /content/drive/MyDrive/new_train_data/images/train/img (1001).jpg
#   inflating: /content/drive/MyDrive/new_train_data/images/train/img (1002).jpg
#   inflating: /content/drive/MyDrive/new_train_data/images/train/img (1003).jpg
#   inflating: /content/drive/MyDrive/new_train_data/images/train/img (1004).jpg
#   inflating: /content/drive/MyDrive/new_train_data/images/train/img (1005).jpg
# ...

# %% [markdown]
# Show image

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source YOLO_dataset/images
display.Image(filename='runs/detect/exp/zidane.jpg', width=600)

# %% [markdown]
# Validation

# %%
# Run YOLOv5x on COCO val (change coco.yaml file by import image path and no of class)
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half

# %% [markdown]
# Test

# %%
# Run YOLOv5x on COCO test (change coco.yaml file by import image path and no of class)
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half --task test

# %% [markdown]
# Train

# %%
# Train YOLOv5s on COCO128 for 3 epochs (change coco128.yaml file by import image path and no of class)
# !python train.py --img 640 --batch 16 --epochs 3 --data custom_coco128.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-80-g55b0096 Python-3.7.13 torch-1.12.1+cu113 CPU
#
# ...

# %% [markdown]
# Evaluate custom detector performance

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()

# %% [markdown]
# Show result

# %%
from utils.plots import plot_results 
plot_results('path/to/results.csv')  # plot 'results.csv' as 'results.png'
